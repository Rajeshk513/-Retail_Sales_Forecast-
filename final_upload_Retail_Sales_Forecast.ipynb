# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/stores_data_set.csv")

# %%
df1
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
df1.head(6)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
# 5      6    A  202505

# %%
df2=pd.read_csv("/content/sales_data_set.csv")

# %%
df2.head(10)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False
# 5      1     1  12/03/2010      21043.39      False
# 6      1     1  19/03/2010      22136.64      False
# 7      1     1  26/03/2010      26229.21      False
# 8      1     1  02/04/2010      57258.43      False
# 9      1     1  09/04/2010      42960.91      False

# %%
d = df2.merge(df1,on=["Store"],how ="inner")

# %%
d
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
df3 = pd.read_csv("/content/Features_data_set.csv")

# %%
df3
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
df = df3.merge(d,on = ['Store','Date'],how = 'inner')

# %%
df
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572        NaN        NaN
# 1           1  05/02/2010        42.31       2.572        NaN        NaN
# 2           1  05/02/2010        42.31       2.572        NaN        NaN
# 3           1  05/02/2010        42.31       2.572        NaN        NaN
# 4           1  05/02/2010        42.31       2.572        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0             NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 421565      100.0     211.94     858.33  192.308899         8.667
# 421566      100.0     211.94     858.33  192.308899         8.667
# 421567      100.0     211.94     858.33  192.308899         8.667
# 421568      100.0     211.94     858.33  192.308899         8.667
# 421569      100.0     211.94     858.33  192.308899         8.667
#
#         IsHoliday_x  Dept  Weekly_Sales  IsHoliday_y Type    Size
# 0             False     1      24924.50        False    A  151315
# 1             False     2      50605.27        False    A  151315
# 2             False     3      13740.12        False    A  151315
# 3             False     4      39954.04        False    A  151315
# 4             False     5      32229.38        False    A  151315
# ...             ...   ...           ...          ...  ...     ...
# 421565        False    93       2487.80        False    B  118221
# 421566        False    94       5203.31        False    B  118221
# 421567        False    95      56017.47        False    B  118221
# 421568        False    97       6817.48        False    B  118221
# 421569        False    98       1076.80        False    B  118221
#
# [421570 rows x 17 columns]

# %%
df.drop(['IsHoliday_y'],axis = 1,inplace = True)

# %%
df
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572        NaN        NaN
# 1           1  05/02/2010        42.31       2.572        NaN        NaN
# 2           1  05/02/2010        42.31       2.572        NaN        NaN
# 3           1  05/02/2010        42.31       2.572        NaN        NaN
# 4           1  05/02/2010        42.31       2.572        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0             NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 421565      100.0     211.94     858.33  192.308899         8.667
# 421566      100.0     211.94     858.33  192.308899         8.667
# 421567      100.0     211.94     858.33  192.308899         8.667
# 421568      100.0     211.94     858.33  192.308899         8.667
# 421569      100.0     211.94     858.33  192.308899         8.667
#
#         IsHoliday_x  Dept  Weekly_Sales Type    Size
# 0             False     1      24924.50    A  151315
# 1             False     2      50605.27    A  151315
# 2             False     3      13740.12    A  151315
# 3             False     4      39954.04    A  151315
# 4             False     5      32229.38    A  151315
# ...             ...   ...           ...  ...     ...
# 421565        False    93       2487.80    B  118221
# 421566        False    94       5203.31    B  118221
# 421567        False    95      56017.47    B  118221
# 421568        False    97       6817.48    B  118221
# 421569        False    98       1076.80    B  118221
#
# [421570 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_x          0
# Dept                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
df
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572       0.00       0.00
# 1           1  05/02/2010        42.31       2.572       0.00       0.00
# 2           1  05/02/2010        42.31       2.572       0.00       0.00
# 3           1  05/02/2010        42.31       2.572       0.00       0.00
# 4           1  05/02/2010        42.31       2.572       0.00       0.00
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0             0.0       0.00       0.00  211.096358         8.106
# 1             0.0       0.00       0.00  211.096358         8.106
# 2             0.0       0.00       0.00  211.096358         8.106
# 3             0.0       0.00       0.00  211.096358         8.106
# 4             0.0       0.00       0.00  211.096358         8.106
# ...           ...        ...        ...         ...           ...
# 421565      100.0     211.94     858.33  192.308899         8.667
# 421566      100.0     211.94     858.33  192.308899         8.667
# 421567      100.0     211.94     858.33  192.308899         8.667
# 421568      100.0     211.94     858.33  192.308899         8.667
# 421569      100.0     211.94     858.33  192.308899         8.667
#
#         IsHoliday_x  Dept  Weekly_Sales Type    Size
# 0             False     1      24924.50    A  151315
# 1             False     2      50605.27    A  151315
# 2             False     3      13740.12    A  151315
# 3             False     4      39954.04    A  151315
# 4             False     5      32229.38    A  151315
# ...             ...   ...           ...  ...     ...
# 421565        False    93       2487.80    B  118221
# 421566        False    94       5203.31    B  118221
# 421567        False    95      56017.47    B  118221
# 421568        False    97       6817.48    B  118221
# 421569        False    98       1076.80    B  118221
#
# [421570 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_x     0
# Dept            0
# Weekly_Sales    0
# Type            0
# Size            0
# dtype: int64

# %%
df.describe()
# Out:
#                Store    Temperature     Fuel_Price      MarkDown1  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      60.090059       3.361027    2590.074819
# std        12.785297      18.447931       0.458515    6052.385934
# min         1.000000      -2.060000       2.472000       0.000000
# 25%        11.000000      46.680000       2.933000       0.000000
# 50%        22.000000      62.090000       3.452000       0.000000
# 75%        33.000000      74.280000       3.738000    2809.050000
# max        45.000000     100.140000       4.468000   88646.760000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      879.974298     468.087665    1083.132268    1662.772385
# std      5084.538801    5528.873453    3894.529945    4207.629321
# min      -265.760000     -29.100000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         2.200000       4.540000     425.290000    2168.040000
# max    104519.540000  141630.610000   67474.850000  108519.280000
#
#                  CPI   Unemployment           Dept   Weekly_Sales  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      171.201947       7.960289      44.260317   15981.258123
# std        39.159276       1.863296      30.492054   22711.183519
# min       126.064000       3.879000       1.000000   -4988.940000
# 25%       132.022667       6.891000      18.000000    2079.650000
# 50%       182.318780       7.866000      37.000000    7612.030000
# 75%       212.416993       8.572000      74.000000   20205.852500
# max       227.232807      14.313000      99.000000  693099.360000
#
#                 Size
# count  421570.000000
# mean   136727.915739
# std     60980.583328
# min     34875.000000
# 25%     93638.000000
# 50%    140167.000000
# 75%    202505.000000
# max    219622.000000

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = pd.to_datetime(df["Date"]).dt.day
df["Week"] = df["Date"].dt.isocalendar().week
# Out:
# <ipython-input-22-af8f1f8936e7>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df[(df['Weekly_Sales'] < 0)].count()
# Out:
# Store           1285
# Date            1285
# Temperature     1285
# Fuel_Price      1285
# MarkDown1       1285
# MarkDown2       1285
# MarkDown3       1285
# MarkDown4       1285
# MarkDown5       1285
# CPI             1285
# Unemployment    1285
# IsHoliday_x     1285
# Dept            1285
# Weekly_Sales    1285
# Type            1285
# Size            1285
# Year            1285
# Month           1285
# Day             1285
# Week            1285
# dtype: int64

# %%
df.drop(df[df['Weekly_Sales'] < 0].index,inplace = True)
df.rename(columns = {"IsHoliday_x":"IsHoliday"},inplace = True)

# %%
df.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 1      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 2      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 3      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 4      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        0.0        0.0  211.096358         8.106      False     1
# 1        0.0        0.0  211.096358         8.106      False     2
# 2        0.0        0.0  211.096358         8.106      False     3
# 3        0.0        0.0  211.096358         8.106      False     4
# 4        0.0        0.0  211.096358         8.106      False     5
#
#    Weekly_Sales Type    Size  Year  Month  Day  Week
# 0      24924.50    A  151315  2010      5    2    17
# 1      50605.27    A  151315  2010      5    2    17
# 2      13740.12    A  151315  2010      5    2    17
# 3      39954.04    A  151315  2010      5    2    17
# 4      32229.38    A  151315  2010      5    2    17

# %%
df["Markdown"] = (df[["MarkDown1", "MarkDown2", "MarkDown3", "MarkDown4", "MarkDown5"]] == 0).all(axis=1).astype(int)

# %%
df["Markdown"].value_counts()
# Out:
# 1    269337
# 0    150948
# Name: Markdown, dtype: int64

# %%
#True - 1,False -0
df.IsHoliday.replace({True :1,False:0},inplace = True)

# %%
df.Type.replace({"A":1,"B":0,"C":-1},inplace = True)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),cmap='crest')
# Out:
# <ipython-input-38-e984ba40f613>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='crest')
# <Axes: >

# %%
df.to_csv("Sales_with_Markdown.csv")

# %%
#Random Forest
y = df["Weekly_Sales"]
x = df.drop(["Weekly_Sales","Date","Size",'Week','Markdown'],axis = 1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=40)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# Cross-Validation R-squared Scores: [0.96467839 0.9597048  0.96484373 0.96691977 0.95780077]
# Average Cross-Validation R-squared Score: 0.9627894904442756

# %%
#ADA BOOST
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Initialize the base estimator (weak learner)
base_estimator = DecisionTreeRegressor(max_depth=100)

# Initialize the AdaBoostRegressor model
model = AdaBoostRegressor(base_estimator=base_estimator)

num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Cross-Validation R-squared Scores: [0.96939339 0.96597616 0.96455906 0.97162841 0.95965199]
# Average Cross-Validation R-squared Score: 0.9662418004708222

# %%
# GRADIENT BOOST

from sklearn.ensemble import GradientBoostingRegressor
y = df["Weekly_Sales"]
x = df.drop(["Weekly_Sales","Date","Size",'Week','Markdown'],axis = 1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

model = GradientBoostingRegressor()

num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# Cross-Validation R-squared Scores: [0.71262809 0.69643529 0.70764944 0.71814421 0.68349112]
# Average Cross-Validation R-squared Score: 0.7036696299874097
